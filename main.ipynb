# %%
import cv2
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# %%
imgs = np.load('back/18.npy')

# %%
imgs.shape
imgs[0].max()
def concat_tile(im_list_2d):
  return cv2.vconcat([cv2.hconcat(im_list_h) for im_list_h in im_list_2d])

# %%
imgs.shape
# Out:
# (64, 320, 320)

# %%
row_list = []
im_list_2d = []
j = 1
for img in imgs:
    img[img<0]=0
    img[img > 0.01]=1
    plt.imshow(img,cmap='seismic',vmax=1,vmin=-1),plt.colorbar(),plt.show()
    M = np.abs(img).max()
    if (j % 8) == 0:
        print(np.array(row_list).shape)
        im_list_2d.append(row_list)
        print(np.array(im_list_2d).shape)
        row_list = []
    else:
        row_list.append(img)
    j += 1
# Out:
# (7, 320, 320)
# (1, 7, 320, 320)
# (7, 320, 320)
# (2, 7, 320, 320)
# (7, 320, 320)
# (3, 7, 320, 320)
# (7, 320, 320)
# (4, 7, 320, 320)
# (7, 320, 320)
# (5, 7, 320, 320)
# (7, 320, 320)
# (6, 7, 320, 320)
# (7, 320, 320)
# (7, 7, 320, 320)
# (7, 320, 320)
# (8, 7, 320, 320)

# %%
cv2.imwrite('save.tif',concat_tile(im_list_2d))
# Out:
# True

# %%
plt.imshow(tile_im, cmap='seismic')
plt.savefig(
            'save.tif',
            orientation='landscape',
            bbox_inches='tight',
            pad_inches=0)

# %%
tile_im = concat_tile(im_list_2d)

# %%
tile_im.shape
# Out:
# (2560, 2240)

# %%
imgs.shape
# Out:
# (64, 320, 320)

# %%
img = sum(imgs)/64
plt.imshow(img,cmap="seismic",vmax=img.max(),vmin=-img.max()),plt.colorbar(),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f5a8334eef0>,
# ...
#  None)

# %%
img.max()
# Out:
# 0.1199033
